# %% [markdown]
# # Creating Dataframes for various portions of the dataset

# %% [markdown]
# ### Step 1 : Importing  and storing the dataset into a general dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv("F:\Datasets for DS club\Spotify clean dataset.csv", encoding_errors = 'replace')

# %%
df
# Out:
#       Unnamed: 0                            Track  \
# 0              0              MILLION DOLLAR BABY
# 1              1                      Not Like Us
# 2              2       i like the way you kiss me
# 3              3                          Flowers
# 4              4                          Houdini
# ...          ...                              ...
# 4588        4595                For the Last Time
# 4589        4596                 Dil Meri Na Sune
# 4590        4597            Grace (feat. 42 Dugg)
# 4591        4598              Nashe Si Chadh Gayi
# 4592        4599  Me Acostumbre (feat. Bad Bunny)
#
#                             Album Name          Artist Release Date  \
# 0         Million Dollar Baby - Single   Tommy Richman   2024-04-26
# 1                          Not Like Us  Kendrick Lamar   2024-05-04
# 2           I like the way you kiss me         Artemas   2024-03-19
# 3                     Flowers - Single     Miley Cyrus   2023-01-12
# ...

# %% [markdown]
# In the cells 4-7, I added a column 'Average Engagement Rate' incase it might be needed for general analysis

# %%
Engagement = ['Spotify Popularity', 'YouTube Engagement Rate', 'TikTok Engagement Rate']

# %%
df['Average Engagement Rate'] = df[Engagement].apply(lambda x: x.mean(), axis=1)

# %%
df['Average Engagement Rate']
# Out:
# 0       35.417352
# 1       37.301228
# 2       33.994949
# 3       31.118884
# 4       34.147900
#           ...
# 4588    28.657329
# 4589    21.733202
# 4590    26.630077
# 4591    24.353117
# 4592    26.255500
# Name: Average Engagement Rate, Length: 4593, dtype: float64

# %%
df
# Out:
#       Unnamed: 0                            Track  \
# 0              0              MILLION DOLLAR BABY
# 1              1                      Not Like Us
# 2              2       i like the way you kiss me
# 3              3                          Flowers
# 4              4                          Houdini
# ...          ...                              ...
# 4588        4595                For the Last Time
# 4589        4596                 Dil Meri Na Sune
# 4590        4597            Grace (feat. 42 Dugg)
# 4591        4598              Nashe Si Chadh Gayi
# 4592        4599  Me Acostumbre (feat. Bad Bunny)
#
#                             Album Name          Artist Release Date  \
# 0         Million Dollar Baby - Single   Tommy Richman   2024-04-26
# 1                          Not Like Us  Kendrick Lamar   2024-05-04
# 2           I like the way you kiss me         Artemas   2024-03-19
# 3                     Flowers - Single     Miley Cyrus   2023-01-12
# ...

# %%
#Checking all the columns in the dataset to begin dividing them into smaller dataframes
df.columns
# Out:
# Index(['Unnamed: 0', 'Track', 'Album Name', 'Artist', 'Release Date', 'ISRC',
#        'All Time Rank', 'Track Score', 'Spotify Streams',
#        'Spotify Playlist Count', 'Spotify Playlist Reach',
#        'Spotify Popularity', 'YouTube Views', 'YouTube Likes', 'TikTok Posts',
#        'TikTok Likes', 'TikTok Views', 'YouTube Playlist Reach',
#        'Apple Music Playlist Count', 'AirPlay Spins', 'SiriusXM Spins',
#        'Deezer Playlist Count', 'Deezer Playlist Reach',
#        'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations',
#        'Soundcloud Streams', 'Shazam Counts', 'Explicit Track',
#        'Total Streams', 'Total Views', 'Radio Airplay',
#        'YouTube Engagement Rate', 'TikTok Engagement Rate',
#        'Average Engagement Rate'],
#       dtype='object')

# %% [markdown]
# ### Step 2 : Creating the dataframes

# %% [markdown]
# ### Procedure followed :
# - Creating a list variable containing all the column names of the columns that will be in the dataframe.
# - Creating the dataframe and using the list variable created to filter only the named columns.
# - Checking the dataframe to ensure all the required columns have been included.

# %% [markdown]
# #### 1. Music Streaming Services Dataframe

# %%
Music_streaming_columns = [ 'Track', 'Album Name', 'Artist', 'Release Date', 'ISRC', 'All Time Rank', 'Track Score', 
                            'Spotify Streams','Spotify Playlist Count', 'Spotify Playlist Reach', 'Spotify Popularity', 
                            'Deezer Playlist Count', 'Deezer Playlist Reach', 'Amazon Playlist Count', 'Pandora Streams', 
                            'Pandora Track Stations', 'Soundcloud Streams', 'Explicit Track']

# %%
Music_streaming_df = df[Music_streaming_columns]

# %%
Music_streaming_df
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4588                For the Last Time                 For the Last Time
# 4589                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4590            Grace (feat. 42 Dugg)                           My Turn
# 4591              Nashe Si Chadh Gayi             November Top 10 Songs
# 4592  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC  All Time Rank  Track Score  \
# ...

# %% [markdown]
# #### 2. Video Sharing and Streaming Platform Dataframe

# %%
Video_sharing_columns = ['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC', 'All Time Rank', 'Track Score',
                        'YouTube Views', 'YouTube Likes', 'YouTube Playlist Reach', 'YouTube Engagement Rate', 'Explicit Track']

# %%
Video_sharing_df = df[Video_sharing_columns]

# %%
Video_sharing_df
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4588                For the Last Time                 For the Last Time
# 4589                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4590            Grace (feat. 42 Dugg)                           My Turn
# 4591              Nashe Si Chadh Gayi             November Top 10 Songs
# 4592  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC  All Time Rank  Track Score  \
# ...

# %% [markdown]
# #### 3. Short-form Video Content Platform Dataframe

# %%
Short_form_Video_columns = ['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC', 'All Time Rank', 'Track Score',
                             'TikTok Posts', 'TikTok Likes', 'TikTok Views', 'TikTok Engagement Rate', 'Explicit Track']

# %%
Short_form_Video_df = df[Short_form_Video_columns]

# %%
Short_form_Video_df
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4588                For the Last Time                 For the Last Time
# 4589                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4590            Grace (feat. 42 Dugg)                           My Turn
# 4591              Nashe Si Chadh Gayi             November Top 10 Songs
# 4592  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC  All Time Rank  Track Score  \
# ...

# %% [markdown]
# #### 4. Radio Airplay Monitoring Dataframe

# %%
Radio_airplay_columns = ['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC', 'All Time Rank', 'Track Score',
                         'AirPlay Spins', 'SiriusXM Spins', 'Radio Airplay', 'Explicit Track']

# %%
Radio_airplay_df = df[Radio_airplay_columns]

# %%
Radio_airplay_df
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4588                For the Last Time                 For the Last Time
# 4589                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4590            Grace (feat. 42 Dugg)                           My Turn
# 4591              Nashe Si Chadh Gayi             November Top 10 Songs
# 4592  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC  All Time Rank  Track Score  \
# ...

# %% [markdown]
# #### 5. Music Identification and Discovery Dataframe

# %%
Music_identification_columns = ['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC', 'All Time Rank', 'Track Score',
                                'Shazam Counts', 'Explicit Track']

# %%
Music_identification_df = df[Music_identification_columns]

# %%
Music_identification_df
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4588                For the Last Time                 For the Last Time
# 4589                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4590            Grace (feat. 42 Dugg)                           My Turn
# 4591              Nashe Si Chadh Gayi             November Top 10 Songs
# 4592  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC  All Time Rank  Track Score  \
# ...
